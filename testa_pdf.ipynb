# %%
import os
from datetime import datetime
import pandas as pd
from IPython.display import display
import pdfplumber
import re

# %%
pdf_path = r"./relat_utilizacao_20250806_203010.pdf"

assert os.path.exists(pdf_path), f"Arquivo não encontrado: {os.path.abspath(pdf_path)}"
print("OK:", os.path.abspath(pdf_path))
# Out:
# OK: c:\Users\leopa\Documents\Projetos\2E\Clínica Santa Saúde\clinicasantasaude\relat_utilizacao_20250806_203010.pdf

# %%
import re
import pdfplumber
import pandas as pd
from IPython.display import display

def normalize_line(s: str) -> str:
    if not s:
        return ""
    return re.sub(r"\s+", " ", s).strip()

RX_SEP1 = re.compile(r'N.? ?Guia ?Operad\.:\s*(\d+)\s+Benefici[áa]rio:\s*([0-9]+)\s*-\s*(.+)$', re.I)
RX_SEP2 = re.compile(r'Senha:\s*([0-9]+).*?Data\s+Solicit\.:\s*(\d{2}/\d{2}/\d{4})', re.I)

# Reconhece início de linha de tabela
RX_ROW_START = re.compile(r'^\s*\d+\s+\d{2}\s+\d+\s*-\s*', re.I)
# Reconhece final de linha completa (tem valor monetário no fim)
RX_MONEY_END = re.compile(r'R\$\s*[\d\.,]+\s*$', re.I)

def parse_row_buffer(buf: str):
    """
    Parser que trata casos onde "R$" se separa e vira apenas "$" com números espalhados
    """
    s = normalize_line(buf)

    # 1) Extrai seq, tabela, procedimento_codigo do início
    m_inicio = re.match(r'^\s*(\d+)\s+(\d{2})\s+(\d{8})', s)
    if not m_inicio:
        return None
    
    seq = int(m_inicio.group(1))
    tabela = m_inicio.group(2)
    proc_cod = m_inicio.group(3)
    
    # 2) Tenta extrair valor normal primeiro (R$ junto)
    m_valor = re.search(r'R\$\s*([\d\.,]+)', s)
    if m_valor:
        valor = float(m_valor.group(1).replace(".", "").replace(",", "."))
        return {
            "seq": seq,
            "tabela": tabela,
            "procedimento_codigo": proc_cod,
            "valor_exec": valor,
        }
    
    # 3) Se não achou "R$", procura por "$" isolado e reconstrói o valor
    m_cifrao = re.search(r'\$', s)
    if m_cifrao:
        print(f"  [DEBUG] Cifrão isolado encontrado em: {s}")
        # Pega tudo após o "$"
        parte_pos_cifrao = s[m_cifrao.end():]
        print(f"  [DEBUG] Parte após $: '{parte_pos_cifrao}'")
        
        # Estratégia: procurar padrão números + vírgula + números
        # Ou se não tiver vírgula, juntar os números sequenciais
        
        # Primeiro tenta encontrar vírgula e pegar números ao redor
        if ',' in parte_pos_cifrao:
            # Tem vírgula - pega números antes e depois da primeira vírgula
            pos_virgula = parte_pos_cifrao.find(',')
            antes_virgula = parte_pos_cifrao[:pos_virgula]
            depois_virgula = parte_pos_cifrao[pos_virgula+1:]
            
            nums_antes = re.findall(r'(\d)', antes_virgula)
            nums_depois = re.findall(r'(\d)', depois_virgula)
            
            print(f"  [DEBUG] Números antes da vírgula: {nums_antes}")
            print(f"  [DEBUG] Números depois da vírgula: {nums_depois}")
            
            if nums_antes and nums_depois:
                # Junta números antes e depois da vírgula
                parte_inteira = ''.join(nums_antes)
                parte_decimal = ''.join(nums_depois[:2])  # máximo 2 casas decimais
                valor_str = f"{parte_inteira},{parte_decimal}"
                print(f"  [DEBUG] Valor reconstruído: {valor_str}")
                valor = float(valor_str.replace(",", "."))
            else:
                print(f"  [DEBUG] Não conseguiu reconstruir valor com vírgula")
                return None
        else:
            # Sem vírgula - pega todos os números e assume últimos 2 são centavos
            nums = re.findall(r'(\d)', parte_pos_cifrao)
            print(f"  [DEBUG] Números encontrados (sem vírgula): {nums}")
            
            if len(nums) >= 2:
                # Assume que os últimos 2 dígitos são centavos
                parte_inteira = ''.join(nums[:-2]) if len(nums) > 2 else '0'
                parte_decimal = ''.join(nums[-2:])
                valor_str = f"{parte_inteira},{parte_decimal}"
                print(f"  [DEBUG] Valor reconstruído: {valor_str}")
                valor = float(valor_str.replace(",", "."))
            elif len(nums) == 1:
                # Apenas um número, assume centavos
                valor = float("0.0" + nums[0])
            else:
                print(f"  [DEBUG] Não conseguiu reconstruir valor")
                return None
        
        return {
            "seq": seq,
            "tabela": tabela,
            "procedimento_codigo": proc_cod,
            "valor_exec": valor,
        }
    
    # Se não encontrou nem "R$" nem "$", falha
    return None

def parse_pdf_text_as_table(pdf_path: str):
    registros = []
    falhas = []

    contexto = {
        "guia_operadora": None,
        "beneficiario_codigo": None,
        "beneficiario_nome": None,
        "senha": None,
        "data_solicitacao": None,
    }

    with pdfplumber.open(pdf_path) as pdf:
        for pidx, page in enumerate(pdf.pages, start=1):
            buffer = ""
            text = page.extract_text() or ""
            
            for raw in text.splitlines():
                linha = normalize_line(raw)

                # Separadores
                m1 = RX_SEP1.search(linha)
                if m1:
                    # Flush buffer antes de mudar contexto
                    if buffer.strip():
                        parsed = parse_row_buffer(buffer)
                        if parsed:
                            registros.append({**contexto, **parsed, "_pagina": pidx, "_linha": buffer})
                        else:
                            falhas.append({"_pagina": pidx, "linha": buffer})
                        buffer = ""
                    
                    contexto["guia_operadora"] = m1.group(1)
                    contexto["beneficiario_codigo"] = m1.group(2)
                    contexto["beneficiario_nome"] = m1.group(3).strip()
                    continue

                m2 = RX_SEP2.search(linha)
                if m2:
                    # Flush buffer antes de mudar contexto
                    if buffer.strip():
                        parsed = parse_row_buffer(buffer)
                        if parsed:
                            registros.append({**contexto, **parsed, "_pagina": pidx, "_linha": buffer})
                        else:
                            falhas.append({"_pagina": pidx, "linha": buffer})
                        buffer = ""
                    
                    contexto["senha"] = m2.group(1)
                    contexto["data_solicitacao"] = m2.group(2)
                    continue

                # Linhas da tabela - ajustar para detectar "$" isolado também
                if RX_ROW_START.match(linha) or buffer:
                    buffer = (buffer + " " + linha).strip() if buffer else linha
                    
                    # Se linha terminou (tem "R$" ou "$"), processa
                    if RX_MONEY_END.search(buffer) or re.search(r'\$', buffer):
                        parsed = parse_row_buffer(buffer)
                        if parsed:
                            registros.append({**contexto, **parsed, "_pagina": pidx, "_linha": buffer})
                        else:
                            falhas.append({"_pagina": pidx, "linha": buffer})
                        buffer = ""

            # Flush final da página
            if buffer.strip():
                parsed = parse_row_buffer(buffer)
                if parsed:
                    registros.append({**contexto, **parsed, "_pagina": pidx, "_linha": buffer})
                else:
                    falhas.append({"_pagina": pidx, "linha": buffer})

    df = pd.DataFrame(registros)
    df_falhas = pd.DataFrame(falhas)
    return df, df_falhas

# %%
df, df_falhas = parse_pdf_text_as_table(pdf_path)
print("Linhas extraídas:", len(df))
print(f"Falhas restantes: {len(df_falhas)}")
if len(df_falhas) > 0:
    display(df_falhas.head(10))
else:
    print("✅ Nenhuma falha!")

display(df.head(20))
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m1e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 9 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m1e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 7 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO01T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L0EUCOGRAMA, PL0AQUETAS) - Exames de PatologRia$ C0l,ín0i0ca
#   [DEBUG] Parte após $: ' C0l,ín0i0ca'
#   [DEBUG] Números antes da vírgula: ['0']
#   [DEBUG] Números depois da vírgula: ['0', '0']
#   [DEBUG] Valor reconstruído: 0,00
#   [DEBUG] Cifrão isolado encontrado em: 2 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO02T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m2e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m2e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m3e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 2 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO03T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 3 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m3e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO03T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 10 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ0DIOS E ELETRO0FORESE LIPOPROTEÍNAS) - ExaRm$e 0s ,d0e0 Patologia Clínica
#   [DEBUG] Parte após $: 'e 0s ,d0e0 Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['0']
#   [DEBUG] Números depois da vírgula: ['0', '0']
#   [DEBUG] Valor reconstruído: 0,00
#   [DEBUG] Cifrão isolado encontrado em: 8 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m3e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m4e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 2 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO04T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m4e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m4e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m5e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m5e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m7e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 2 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO07T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m9e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 5 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m9e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 15 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO09T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 5 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m9e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 5 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO09T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa0m9e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m0e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m0e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 9 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m1e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 7 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ0DIOS E ELETRO0FORESE LIPOPROTEÍNAS) - ExaRm$e 0s ,d0e0 Patologia Clínica
#   [DEBUG] Parte após $: 'e 0s ,d0e0 Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['0']
#   [DEBUG] Números depois da vírgula: ['0', '0']
#   [DEBUG] Valor reconstruído: 0,00
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m1e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 9 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m2e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 6 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO12T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 2 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO14T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m4e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m4e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 11 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m4e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 10 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO14T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 19 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m4e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 15 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO14T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m5e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 2 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO15T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m5e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m5e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 17 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m6e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 16 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO16T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m6e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m6e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m6e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 11 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO16T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m6e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 9 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m7e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 7 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO17T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m7e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 9 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m8e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 7 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO18T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 2 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ0DIOS E ELETRO0FORESE LIPOPROTEÍNAS) - ExaRm$e 0s ,d0e0 Patologia Clínica
#   [DEBUG] Parte após $: 'e 0s ,d0e0 Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['0']
#   [DEBUG] Números depois da vírgula: ['0', '0']
#   [DEBUG] Valor reconstruído: 0,00
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m8e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 2 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa1m8e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 2 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m2e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 10 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO22T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 9 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m2e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 2 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO22T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m2e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 24 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO22T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 16 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m2e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m2e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m2e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 9 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m2e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 7 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO22T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m2e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 9 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m2e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 7 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO22T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m3e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 3 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO23T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m3e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 4 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO23T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m3e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 9 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m3e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 7 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO23T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m3e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 2 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO24T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m4e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 6 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO24T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 4 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m4e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 6 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m5e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 3 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO25T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m5e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 14 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m5e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 17 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO26T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m6e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 5 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO28T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m8e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m8e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m8e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 3 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m8e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L0EUCOGRAMA, PL0AQUETAS) - Exames de PatologRia$ C0l,ín0i0ca
#   [DEBUG] Parte após $: ' C0l,ín0i0ca'
#   [DEBUG] Números antes da vírgula: ['0']
#   [DEBUG] Números depois da vírgula: ['0', '0']
#   [DEBUG] Valor reconstruído: 0,00
#   [DEBUG] Cifrão isolado encontrado em: 8 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L0EUCOGRAMA, PL0AQUETAS) - Exames de PatologRia$ C0l,ín0i0ca
#   [DEBUG] Parte após $: ' C0l,ín0i0ca'
#   [DEBUG] Números antes da vírgula: ['0']
#   [DEBUG] Números depois da vírgula: ['0', '0']
#   [DEBUG] Valor reconstruído: 0,00
#   [DEBUG] Cifrão isolado encontrado em: 10 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa2m9e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 6 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO29T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 11 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO29T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 2 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L0EUCOGRAMA, PL0AQUETAS) - Exames de PatologRia$ C0l,ín0i0ca
#   [DEBUG] Parte após $: ' C0l,ín0i0ca'
#   [DEBUG] Números antes da vírgula: ['0']
#   [DEBUG] Números depois da vírgula: ['0', '0']
#   [DEBUG] Valor reconstruído: 0,00
#   [DEBUG] Cifrão isolado encontrado em: 9 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa3m0e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 7 00 40302750 - PERFIL LIPÍDICO / LIPIDOGRAMA (LIPÍDIOS TOTAIS, COLESTER1OL, TRIGLICERÍ1DIOS E ELETRO1FORESE LIPOPRO30T/E0Í7N/A2S0)2 5- ExaRm$e 3s 6d,e7 9Patologia Clínica
#   [DEBUG] Parte após $: 'e 3s 6d,e7 9Patologia Clínica'
#   [DEBUG] Números antes da vírgula: ['3', '6']
#   [DEBUG] Números depois da vírgula: ['7', '9']
#   [DEBUG] Valor reconstruído: 36,79
#   [DEBUG] Cifrão isolado encontrado em: 13 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa3m0e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 28 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa3m0e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 17 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa3m1e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
#   [DEBUG] Cifrão isolado encontrado em: 25 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQUETAS OU FRAÇÕES (ER1ITROGRAMA, L1EUCOGRAMA, PL1AQUETAS) - Exa3m1e/0s 7d/e2 0P2a5tologRia$ C9l,ín6i9ca
#   [DEBUG] Parte após $: ' C9l,ín6i9ca'
#   [DEBUG] Números antes da vírgula: ['9']
#   [DEBUG] Números depois da vírgula: ['6', '9']
#   [DEBUG] Valor reconstruído: 9,69
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Linhas extraídas: 1835
# Falhas restantes: 0
# ✅ Nenhuma falha!
#    guia_operadora beneficiario_codigo        beneficiario_nome       senha  \
# 0       172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 1       172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 2       172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 3       172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 4       172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 5       172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 6       172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 7       172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 8       172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 9       172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 10      172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 11      172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 12      172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 13      172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 14      172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 15      172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 16      172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 17      172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 18      172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
# 19      172381231    0001000190990004  IRACILDA CORREIA SANTOS  1723812312
#
#    data_solicitacao  seq tabela procedimento_codigo  valor_exec  _pagina  \
# 0        01/07/2025   20     00            40303136       10.52        1
# 1        01/07/2025   19     00            40303110       10.52        1
# 2        01/07/2025   18     00            40302733        0.00        1
# 3        01/07/2025   17     00            40302547        6.04        1
# 4        01/07/2025   16     00            40302695        8.03        1
# 5        01/07/2025   15     00            40301591        8.03        1
# 6        01/07/2025   14     00            40301583        6.04        1
# 7        01/07/2025   13     00            40301605        4.35        1
# 8        01/07/2025   12     00            40301150        4.35        1
# 9        01/07/2025   11     00            40311171        0.00        1
# 10       01/07/2025   10     00            40311210        9.22        1
# 11       01/07/2025    9     00            40302318        4.35        1
# 12       01/07/2025    8     00            40301630        4.35        1
# 13       01/07/2025    7     00            40302580        4.35        1
# 14       01/07/2025    6     00            40712273       14.51        1
# 15       01/07/2025    5     00            40301931        4.35        1
# 16       01/07/2025    4     00            40302237        4.35        2
# 17       01/07/2025    3     00            40302423        4.35        2
# 18       01/07/2025    2     00            40301400        4.35        2
# 19       01/07/2025    1     00            40304361        9.69        2
#
#                                                _linha
# 0   20 00 40303136 - SANGUE OCULTO, PESQUISA - Exa...
# 1   19 00 40303110 - PARASITOLOGICO - Exames de Pa...
# 2   18 00 40302733 - HEMOGLOBINA GLICADA (FRAÇÃO A...
# 3   17 00 40302547 - TRIGLICERIDEOS - Exames de Pa...
# 4   16 00 40302695 - COLESTEROL (VLDL) - Exames de...
# 5   15 00 40301591 - COLESTEROL (LDL) - Exames de ...
# 6   14 00 40301583 - COLESTEROL (HDL) - Exames de ...
# 7   13 00 40301605 - COLESTEROL TOTAL - Exames de ...
# 8   12 00 40301150 - ACIDO URICO - Exames de Patol...
# 9   11 00 40311171 - MICROALBUMINURIA - Exames de ...
# 10  10 00 40311210 - ROTINA DE URINA (CARACTERES F...
# 11  9 00 40302318 - POTASSIO - Exames de Patologia...
# 12  8 00 40301630 - CREATININA - Exames de Patolog...
# 13  7 00 40302580 - UREIA - Exames de Patologia Cl...
# 14  6 00 40712273 - FERRITINA - Exames de Medicina...
# 15  5 00 40301931 - FOSFORO - Exames de Patologia ...
# 16  4 00 40302237 - MAGNESIO - Exames de Patologia...
# 17  3 00 40302423 - SODIO - Exames de Patologia Cl...
# 18  2 00 40301400 - CALCIO - Exames de Patologia C...
# 19  1 00 40304361 - HEMOGRAMA COM CONTAGEM DE PLAQ...

# %%
df.groupby('beneficiario_nome')['valor_exec'].sum()
# Out:
# beneficiario_nome
# ADRIANA ALEMAO SANTOS NOBRE              223.65
# ALBANI DE MELO ROCHA SANTANA             149.86
# ALBERTO BEDOIA DO NASCIMENTO             148.33
# ALDANUZIA PEREIRA SILVA NASCIMENTO       114.40
# ALEXANDRA PEREIRA NASCIMENTO              84.00
#                                           ...
# VANUZIA MARIA DE JESUS DOS SANTOS         60.00
# VERA LUCIA GONCALVES PEREIRA ASSUNCAO    171.40
# VICENTE JOSE SOBRINHO                     89.63
# VICTOR GABRIEL RIBEIRO NORONHA            60.00
# ZILMA VIEIRA SANTANA SANTOS              157.38
# Name: valor_exec, Length: 239, dtype: float64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import re

def test_parse_line_simples(linha):
    """
    Parser simplificado: apenas Seq, Tabela, Procedimento (8 dígitos) e Valor Exec.
    Ignora todas as colunas intermediárias (quantidades, data exec)
    """
    
    # 1) Extrai seq, tabela, procedimento_codigo do início
    m_inicio = re.match(r'^\s*(\d+)\s+(\d{2})\s+(\d{8})', linha.strip())
    if not m_inicio:
        return None
    
    seq = int(m_inicio.group(1))
    tabela = m_inicio.group(2)
    proc_cod = m_inicio.group(3)
    
    # 2) Extrai valor (sempre presente, em qualquer lugar da linha)
    m_valor = re.search(r'R\$\s*([\d\.,]+)', linha)
    if not m_valor:
        return None
    
    valor = float(m_valor.group(1).replace(".", "").replace(",", "."))
    
    return {
        "seq": seq,
        "tabela": tabela,
        "procedimento_codigo": proc_cod,
        "valor_exec": valor
    }

# Teste com as linhas problemáticas
linhas_teste = [
    "18 00 40302733 - HEMOGLOBINA GLICADA (FRAÇÃO A1C) - Exames de Patologia C1línica 0 0 R$ 0,00",
    "17 00 40302547 - TRIGLICERIDEOS - Exames de Patologia Clínica 1 1 1 01/07/2025 R$ 6,04",
    "10 00 40311210 - ROTINA DE URINA (CARACTERES FISICOS, ELEMENTOS ANORM1AIS E SEDIMENT1OSCOPIA) - Exa1mes de Patologi0a1 C/0lín7i/c2a025 R$ 9,22"
]

for i, linha in enumerate(linhas_teste, 1):
    print(f"\n=== TESTE {i} ===")
    print(f"Linha: {linha}")
    resultado = test_parse_line_simples(linha)
    if resultado:
        print(f"Resultado: {resultado}")
    else:
        print("FALHA no parsing")
# Out:
# === TESTE 1 ===
# Linha: 18 00 40302733 - HEMOGLOBINA GLICADA (FRAÇÃO A1C) - Exames de Patologia C1línica 0 0 R$ 0,00
# Resultado: {'seq': 18, 'tabela': '00', 'procedimento_codigo': '40302733', 'valor_exec': 0.0}
#
# === TESTE 2 ===
# Linha: 17 00 40302547 - TRIGLICERIDEOS - Exames de Patologia Clínica 1 1 1 01/07/2025 R$ 6,04
# Resultado: {'seq': 17, 'tabela': '00', 'procedimento_codigo': '40302547', 'valor_exec': 6.04}
#
# === TESTE 3 ===
# Linha: 10 00 40311210 - ROTINA DE URINA (CARACTERES FISICOS, ELEMENTOS ANORM1AIS E SEDIMENT1OSCOPIA) - Exa1mes de Patologi0a1 C/0lín7i/c2a025 R$ 9,22
# Resultado: {'seq': 10, 'tabela': '00', 'procedimento_codigo': '40311210', 'valor_exec': 9.22}

# %%
len('18 00 40302733 - HEMOGLOBINA GLICADA (FRAÇÃO A1C) - Exames de Patologia C1línica 0 0 R$ 0,00')
# Out:
# 92
